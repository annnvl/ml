# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn import model_selection, preprocessing
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import auc
from sklearn.preprocessing import OneHotEncoder, LabelEncoder
import collections
import seaborn as sns
import matplotlib.pyplot as plt
import math
import scipy.stats as sps
# %matplotlib inline

# %%
data = pd.read_csv('task2_lemmas_train').fillna('')
test = pd.read_csv('task2_lemmas_test', index_col=0).fillna('')

# %%
newdata = data
for col in ['y1','y2','y3','y4']:
    newdata = newdata.select(lambda x: len(newdata[col][x]) > 0)
    print(newdata.head())
    newdata['y'] = newdata[col]
    data = data.append(newdata)
olddata = data.copy()
# Out:
#       Id            X                y              y1 y2 y3 y4
# 100  101      provata        provare+V       provato+A
# 227  228  complimento  complimentare+V   complimento+N
# 295  296      rampino        rampino+N       rampare+V
# 371  372   sussidiari    sussidiario+A   sussidiario+N
# 397  398   squalifica     squalifica+N  squalificare+V
#         Id           X             y            y1            y2 y3 y4
# 1209  1210     passati     passato+A     passato+A     passare+V
# 2397  2398       calmo       calmo+A       calmo+A     calmare+V
# 3921  3922  crocifissi  crocifisso+N  crocifisso+N  crocifisso+A
# 4972  4973     massimo     massimo+N     massimo+N      grande+A
# 6673  6674     vestite     vestire+V     vestire+V     vestito+A
#           Id        X           y        y1          y2          y3  \
# 20393  20394  siedevo  risedere+A  sedere+A  risedere+A  risedere+V
#
#                    y4
# 20393  soprassedere+V
#           Id        X           y        y1          y2          y3  \
# 20393  20394  siedevo  risedere+V  sedere+A  risedere+A  risedere+V
#
#                    y4
# 20393  soprassedere+V

# %%
data = olddata

# %%
data = data[['X','y']]
data['PoS'] = data['y'].map(lambda x: x[-1:])
data['y'] = data['y'].map(lambda x: x[:-2])
data.head()
# Out:
#               X            y PoS
# 0  vergognerete   vergognare   V
# 1  amnistiavate   amnistiare   V
# 2   menomazione  menomazione   N
# 3    sfaldavamo     sfaldare   V
# 4    sfodererei    sfoderare   V

# %%
exp_data = data.copy()
exp_data['X_beg'] = exp_data['X_end'] = exp_data['X']

for x in exp_data.iterrows():
    i = 0
    while(x[1]['X'][i] == x[1]['y'][i]):
        i+=1
        if(i == len(x[1]['y']) or i == len(x[1]['X'])):
            x[1]['X_end'] = x[1]['y'] = ''
            x[1]['X_beg'] = x[1]['X']
            break
    
    if(i < len(x[1]['y'])):
        x[1]['X_beg'] = x[1]['X'][:i-1]
        x[1]['X_end'] = x[1]['X'][i-1:]
        x[1]['y'] = x[1]['y'][i-1:]

# %%
exp_data.head(n=200)
# Out:
#                      X        y PoS            X_beg       X_end
# 0         vergognerete     nare   V           vergog      nerete
# 1         amnistiavate      are   V          amnisti       avate
# 2          menomazione            N      menomazione
# 3           sfaldavamo      are   V            sfald       avamo
# 4           sfodererei     rare   V            sfode       rerei
# 5           ascondesti      ere   V           ascond        esti
# 6        edifichereste     care   V            edifi    chereste
# 7           maschieran     iare   V            masch       ieran
# 8        transennasser      are   V         transenn       asser
# 9           computando      are   V           comput        ando
# 10          accudisser      ire   V            accud       isser
# 11        diromperanno       re   V          dirompe       ranno
# 12       intercollegai      are   V      intercolleg          ai
# 13          integrando      are   V           integr        ando
# 14       sbramerebbero     mare   V             sbra   merebbero
# 15   stravaccherebbero     care   V          stravac  cherebbero
# 16      oltrepassasser      are   V        oltrepass       asser
# 17         cauzionavan      are   V          cauzion        avan
# 18         scarrozzata      are   V         scarrozz         ata
# 19      intossicassero      are   V         intossic      assero
# 20            incurvan      are   V           incurv          an
# 21             zufolan      are   V            zufol          an
# 22         impiastrate      are   V         impiastr         ate
# 23     trivellerebbero     lare   V           trivel   lerebbero
# 24       pizzicottassi      are   V        pizzicott        assi
# 25     spoliticizzasti      are   V      spoliticizz        asti
# 26              rombar            V           rombar
# 27      scapricceremmo    ciare   V          scapric     ceremmo
# 28     intrometterebbe            V  intrometterebbe
# 29      lavoricchiassi      are   V       lavoricchi        assi
# ..                 ...      ...  ..              ...         ...
# 170    sventaglierebbe     iare   V         sventagl     ierebbe
# 171           criptava      are   V            cript         ava
# 172       vestibolante      are   A         vestibol        ante
# 173           mediasse      are   V             medi        asse
# 174            cociamo  cuocere   V                      cociamo
# 175     ricongiungesse      ere   V       ricongiung        esse
# 176       circonvenita      ire   V        circonven         ita
# 177          addiviene   venire   V             addi       viene
# 178           smarrita      ire   V            smarr         ita
# 179         contitolar            V       contitolar
# 180        raffreniamo     nare   V           raffre       niamo
# 181          demagoghi       go   N           demago         ghi
# 182       ingannatrice     tore   A          inganna       trice
# 183      risciogliemmo      ere   V        risciogli        emmo
# 184        idoleggiati      are   V         idoleggi         ati
# 185          cogestivo      ire   V           cogest         ivo
# 186        ingigantivi      ire   V         ingigant         ivi
# 187  autodiagnosticano      are   V   autodiagnostic         ano
# 188      raccoglimenti       to   N      raccoglimen          ti
# 189       contenessimo      ere   V           conten      essimo
# 190  compenetrerebbero     rare   V         compenet   rerebbero
# 191        impeciasser      are   V           impeci       asser
# 192         designerai     nare   V            desig       nerai
# 193               fola            N             fola
# 194          investirà       re   V          investi          rà
# 195            permutò     tare   V            permu          tò
# 196            attinte    ngere   V             atti         nte
# 197         rinsaldato      are   V          rinsald         ato
# 198             stereo            N           stereo
# 199          incuterei            V        incuterei
#
# [200 rows x 5 columns]

# %%
def sortByLength(inputStr):
        return len(inputStr)
endings = np.unique(exp_data[['X_end', 'y']].as_matrix().reshape(-1)).tolist()
endings.sort(key=sortByLength)
print(endings)
# Out:
# ['', 'a', 'e', 'i', 'n', 'o', 'r', 'u', 'à', 'ò', 'ae', 'ai', 'an', 'ax', 'ba', 'be', 'bi', 'bo', 'by', 'bè', 'bì', 'bò', 'ca', 'ce', 'ci', 'co', 'cè', 'cì', 'cò', 'da', 'de', 'di', 'do', 'dè', 'dì', 'dò', 'ea', 'ee', 'ei', 'eo', 'eò', 'fa', 'fe', 'fi', 'fo', 'fì', 'fò', 'ga', 'ge', 'gi', 'go', 'gè', 'gì', 'gò', 'ha', 'he', 'hi', 'ho', 'hì', 'ia', 'ie', 'ii', 'in', 'io', 'iè', 'iò', 'ka', 'ke', 'ki', 'ko', 'kò', 'la', 'le', 'li', 'lo', 'lè', 'lì', 'lò', 'ma', 'me', 'mi', 'mo', 'mè', 'mì', 'mò', 'na', 'ne', 'ni', 'no', 'nè', 'nì', 'nò', 'oa', 'oe', 'oi', 'oì', 'pa', 'pe', 'pi', 'po', 'pè', 'pì', 'pò', 'ra', 're', 'ri', 'ro', 'rà', 'rì', 'rò', 'sa', 'se', 'si', 'so', 'sè', 'sì', 'sò', 'ta', 'te', 'ti', 'to', 'ty', 'tè', 'tì', 'tò', 'ua', 'ue', 'ui', 'uo', 'uè', 'uì', 'uò', 'va', 've', 'vi', 'vo', 'vè', 'vì', 'vò', 'za', 'ze', 'zi', 'zo', 'zì', 'zò', 'ìa', 'ìe', 'ìi', 'ìo', 'aia', 'aio', 'amo', 'ano', 'are', 'asa', 'ase', 'asi', 'aso', 'asè', 'ata', 'ate', 'ati', 'ato', 'ava', 'avi', 'avo', 'ban', 'bin', 'bon', 'can', 'che', 'chi', 'cia', 'cio', 'con', 'dan', 'dde', 'ddi', 'dei', 'din', 'dio', 'don', 'drà', 'drò', 'dèi', 'ein', 'era', 'ere', 'eri', 'ero', 'esa', 'ese', 'esi', 'eso', 'esè', 'ete', 'eva', 'evi', 'evo', 'fan', 'fin', 'fon', 'gan', 'ghe', 'ghi', 'gia', 'gio', 'gon', 'han', 'hon', 'ian', 'ica', 'ice', 'ici', 'ico', 'iin', 'ino', 'ion', 'ire', 'isa', 'ise', 'isi', 'iso', 'ita', 'ite', 'iti', 'ito', 'iva', 'ivi', 'ivo', 'lan', 'lga', 'lgo', 'lin', 'lle', 'lli', 'lon', 'lsa', 'lse', 'lsi', 'lso', 'lta', 'lte', 'lti', 'lto', 'man', 'men', 'min', 'mon', 'nan', 'nga', 'ngo', 'nin', 'nne', 'nni', 'non', 'nse', 'nsi', 'nsè', 'nta', 'nte', 'nti', 'nto', 'one', 'oni', 'onè', 'osa', 'ose', 'osi', 'oso', 'osè', 'pan', 'pin', 'pon', 'può', 'rai', 'ran', 'rin', 'ron', 'rsa', 'rse', 'rsi', 'rso', 'rsè', 'rta', 'rte', 'rti', 'rto', 'rve', 'rvi', 'san', 'sin', 'son', 'tan', 'tia', 'tin', 'ton', 'trà', 'trò', 'uan', 'uca', 'uce', 'uci', 'uco', 'ucè', 'uin', 'uon', 'usa', 'use', 'usi', 'uso', 'usè', 'van', 'vin', 'von', 'vrà', 'vrò', 'zin', 'aces', 'aete', 'aeva', 'aevi', 'aevo', 'agga', 'aggo', 'aian', 'aion', 'aire', 'ammo', 'ando', 'anno', 'ante', 'anti', 'arre', 'arrà', 'arrò', 'arsi', 'aser', 'asse', 'assi', 'asta', 'aste', 'asti', 'asto', 'atta', 'atte', 'atti', 'atto', 'avan', 'bano', 'bare', 'bere', 'berà', 'berò', 'bies', 'bino', 'bire', 'bono', 'bute', 'buti', 'buto', 'cano', 'care', 'ccia', 'ccio', 'cere', 'cerà', 'cerò', 'chin', 'cian', 'cion', 'cire', 'cono', 'cque', 'cqui', 'cuta', 'cute', 'cuti', 'cuto', 'dano', 'dare', 'dder', 'dere', 'derà', 'derò', 'dino', 'dire', 'dono', 'drai', 'dran', 'drei', 'duta', 'dute', 'duti', 'duto', 'eare', 'ebbe', 'ebbi', 'eerà', 'eerò', 'eino', 'elga', 'elgo', 'elsi', 'elsè', 'elte', 'emmo', 'endo', 'ente', 'enti', 'eran', 'errà', 'errò', 'eser', 'essa', 'esse', 'essi', 'esso', 'essè', 'este', 'esti', 'etta', 'ette', 'etti', 'etto', 'evan', 'fano', 'fare', 'fece', 'feci', 'ferà', 'ferò', 'fino', 'fire', 'fono', 'fusa', 'fuse', 'fusi', 'fuso', 'gano', 'gare', 'gere', 'gerà', 'gerò', 'ghin', 'gire', 'gono', 'hano', 'hire', 'hono', 'iamo', 'iano', 'iare', 'iate', 'ican', 'icon', 'iere', 'ierà', 'ierò', 'iino', 'immo', 'iono', 'isca', 'isce', 'isci', 'isco', 'iser', 'issa', 'isse', 'issi', 'isso', 'issè', 'iste', 'isti', 'itta', 'itte', 'itti', 'itto', 'iuta', 'iuto', 'ivan', 'kare', 'kerà', 'kerò', 'kino', 'lano', 'lare', 'lere', 'lerà', 'lerò', 'lgan', 'lgon', 'lino', 'lire', 'lono', 'lser', 'luta', 'lute', 'luti', 'luto', 'mano', 'mare', 'mere', 'merà', 'merò', 'mini', 'mino', 'mire', 'mise', 'misi', 'mono', 'muta', 'muti', 'muto', 'nano', 'nare', 'nere', 'nerà', 'nerò', 'ngan', 'ngon', 'nino', 'nire', 'nner', 'nono', 'nser', 'nuta', 'nute', 'nuti', 'nuto', 'obbi', 'oire', 'olgo', 'olsi', 'olsè', 'olta', 'olti', 'olto', 'onei', 'onga', 'ongo', 'orre', 'orrà', 'orrò', 'oser', 'ossa', 'osta', 'oste', 'osti', 'osto', 'otta', 'otte', 'otti', 'otto', 'pano', 'pare', 'pere', 'perà', 'però', 'pino ...

# %%
var = exp_data.copy()

# %%
exp_data['X_end_new'] = exp_data['X'].map(lambda x: [x])
for ending in endings:
    exp_data['X_end_new'] = exp_data['X_end_new'].map(lambda x: x + [ending] if len(x[0]) >= len(ending) and x[0][-len(ending):] == ending else x)
exp_data.head()
# Out:
#               X       y PoS     X_beg   X_end  \
# 0  vergognerete  nare+V   V    vergog  nerete
# 1  amnistiavate   are+V   V   amnisti   avate
# 2   menomazione   one+N   N  menomazi     one
# 3    sfaldavamo   are+V   V     sfald   avamo
# 4    sfodererei  rare+V   V     sfode   rerei
#
#                             X_end_new
# 0  [vergognerete, e, te, ete, nerete]
# 1   [amnistiavate, e, te, ate, avate]
# 2           [menomazione, e, ne, one]
# 3     [sfaldavamo, o, mo, amo, avamo]
# 4          [sfodererei, i, ei, rerei]

# %%
exp_data.loc[train['X_end'] == 's']
# Out:
#                     X    y PoS         X_beg X_end X_end_new
# 2957        toilettes   +N   N      toilette     s         s
# 5383          brokers   +N   N        broker     s         s
# 5526         brioches   +N   N       brioche     s         s
# 12115      anti-gates  s+A   A     anti-gate     s         s
# 17308          tennis  s+N   N         tenni     s         s
# 17315        partners   +N   N       partner     s         s
# 18500          plazas   +N   N         plaza     s         s
# 20670          vulnus  s+N   N         vulnu     s         s
# 22550            rais  s+N   N           rai     s         s
# 24066     rendez-vous  s+N   N    rendez-vou     s         s
# 25251           pages   +N   N          page     s         s
# 28066             gas  s+N   N            ga     s         s
# 29243         minibus  s+N   N        minibu     s         s
# 36820      videogames   +N   N     videogame     s         s
# 37404     condiciones        N    condicione     s         s
# 39118         bohèmes   +N   N        bohème     s         s
# 40496       flamencos   +N   N      flamenco     s         s
# 45231          cactus  s+N   N         cactu     s         s
# 54396         by-pass  s+N   N        by-pas     s         s
# 55233       squatters   +N   N      squatter     s         s
# 59044             vis  s+N   N            vi     s         s
# 59213              ds  s+N   N             d     s         s
# 60239          peones   +N   N         peone     s         s
# 61588            paìs  s+N   N           paì     s         s
# 63352     task-forces   +N   N    task-force     s         s
# 65710          machos   +N   N         macho     s         s
# 68376          pieces   +N   N         piece     s         s
# 69021             bis  s+A   A            bi     s         s
# 69572            mais  s+N   N           mai     s         s
# 74977    performances   +N   N   performance     s         s
# 76769             sos  s+N   N            so     s         s
# 79703      vigilantes  s+N   N     vigilante     s         s
# 81083          relais  s+N   N         relai     s         s
# 86882            deus  s+N   N           deu     s         s
# 87074       hooligans   +N   N      hooligan     s         s
# 88807          ratios   +N   N         ratio     s         s
# 89069        palmarès  s+N   N       palmarè     s         s
# 89262          ananas  s+N   N         anana     s         s
# 91400         futures  s+N   N        future     s         s
# 91757        buvettes   +N   N       buvette     s         s
# 92303        pancreas  s+N   N       pancrea     s         s
# 93350        coutures   +N   N       couture     s         s
# 95471   prorogationes        N  prorogatione     s         s
# 97975          gaffes   +N   N         gaffe     s         s
# 102189         volées   +N   N         volée     s         s
# 103858          pesos  s+N   N          peso     s         s
# 107780      reporters   +N   N      reporter     s         s
# 111215   conventiones        N   conventione     s         s
# 111801          ictus  s+N   N          ictu     s         s
# 114762    bestsellers   +N   N    bestseller     s         s
# 115309         scores   +N   N         score     s         s
# 116904         pathos  s+N   N         patho     s         s

# %%
exp_data['X_end_new'] = exp_data['X_end_new'].map(lambda x: x if len(x)>1 else x + [x[0][-1]])
exp_data['X_beg'] = exp_data['X_end_new'].map(lambda x: x[0][:-len(x[-1])])
exp_data['y'] = olddata['y']
exp_data['X_end_new'] = exp_data['X_end_new'].map(lambda x: x[-1] if len(x)>1 else x[0][-1])
for x in exp_data.iterrows():
    x[1]['y'] = x[1]['y'][len(x[1]['X_beg']):]
exp_data.head()
# Out:
#               X       y PoS     X_beg   X_end X_end_new
# 0  vergognerete  nare+V   V    vergog  nerete    nerete
# 1  amnistiavate   are+V   V   amnisti   avate     avate
# 2   menomazione   one+N   N  menomazi     one       one
# 3    sfaldavamo   are+V   V     sfald   avamo     avamo
# 4    sfodererei  rare+V   V     sfode   rerei     rerei

# %%
exp_data['X_end'] = exp_data['X_end_new']
train = exp_data[['X_beg', 'X_end', 'y']]
train.head()
# Out:
#       X_beg   X_end       y
# 0    vergog  nerete  nare+V
# 1   amnisti   avate   are+V
# 2  menomazi     one   one+N
# 3     sfald   avamo   are+V
# 4     sfode   rerei  rare+V

# %%
endings = np.unique(exp_data[['X_end', 'y']].as_matrix().reshape(-1)).tolist()
exp_test = test.copy()
exp_test.head()
# Out:
#                  X        X_beg X_end       target
# 1         gettonan        getto   nan        getto
# 2      incidentali    incidenta    li    incidenta
# 3        involtino        invol  tino        invol
# 4            lievi           li   evi           li
# 5  comunistizzasse  comunistizz  asse  comunistizz

# %%
exp_test['X_end'] = exp_test['X'].map(lambda x: [x])
for ending in endings:
    exp_test['X_end'] = exp_test['X_end'].map(lambda x: x + [ending] if len(x[0]) >= len(ending) and x[0][-len(ending):] == ending else x)
exp_test.head()
# Out:
#                  X        X_beg                           X_end       target
# 1         gettonan        getto          [gettonan, an, n, nan]        getto
# 2      incidentali    incidenta            [incidentali, i, li]    incidenta
# 3        involtino        invol   [involtino, ino, no, o, tino]        invol
# 4            lievi           li             [lievi, evi, i, vi]           li
# 5  comunistizzasse  comunistizz  [comunistizzasse, asse, e, se]  comunistizz

# %%
exp_test['X_beg'] = exp_test['X_end'].map(lambda x: x[0][:-len(x[-1])])
exp_test['X_end'] = exp_test['X_end'].map(lambda x: x[-1] if len(x)>1 else x[0][-1])
exp_test = exp_test[['X', 'X_beg', 'X_end']]
exp_test.head()
# Out:
#                  X          X_beg X_end
# 1         gettonan          getto   nan
# 2      incidentali      incidenta    li
# 3        involtino          invol  tino
# 4            lievi            lie    vi
# 5  comunistizzasse  comunistizzas    se

# %%
training_set = train[['X_end', 'y']]
training_set.loc[train['X_end'] == 'an']
# Out:
#        X_end      y
# 931       an  are+V
# 1103      an  are+V
# 1473      an  are+V
# 2052      an  are+V
# 2566      an  are+V
# 2787      an  are+V
# 3727      an  are+V
# 4015      an  are+V
# 4690      an  are+V
# 5747      an  are+V
# 6262      an  are+V
# 6627      an  are+V
# 6728      an  are+V
# 7863      an  are+V
# 8061      an  are+V
# 10021     an  are+V
# 11723     an  are+V
# 13199     an  are+V
# 14167     an  are+V
# 15233     an  are+V
# 15867     an  are+V
# 16632     an  are+V
# 17552     an  are+V
# 17765     an  are+V
# 17917     an  are+V
# 18834     an  are+V
# 18948     an  are+V
# 20675     an  are+V
# 20850     an  are+V
# 22190     an  are+V
# ...      ...    ...
# 97915     an  are+V
# 97922     an  are+V
# 98683     an  are+V
# 99516     an  are+V
# 99532     an  are+V
# 99617     an  are+V
# 100336    an  are+V
# 100715    an  are+V
# 102601    an  are+V
# 102722    an  are+V
# 104459    an  are+V
# 104594    an  are+V
# 106354    an  are+V
# 106416    an  are+V
# 106801    an  are+V
# 108106    an  are+V
# 108763    an  are+V
# 109607    an  are+V
# 109630    an  are+V
# 110990    an  are+V
# 111025    an  are+V
# 111262    an  are+V
# 112317    an  are+V
# 112882    an  are+V
# 113265    an  are+V
# 113311    an  are+V
# 114116    an  are+V
# 116896    an  are+V
# 116967    an  are+V
# 117565    an  are+V
#
# [155 rows x 2 columns]

# %%
active_endings = set(exp_test['X_end'])
unknown = active_endings.difference(set(endings))
active_endings.intersection_update(set(endings))
active_endings.difference(set(endings))
# Out:
# set()

# %%
test = exp_test.copy()
test['target'] = test['X_beg']

for x in test.iterrows():
    if(x[1]['X_end'] in unknown):
        x[1]['target'] = x[1]['X'] + '+N'

test.loc[test['X_end'] == 'j']
# Out:
#         X X_beg X_end target
# 26266  dj           j   dj+N

# %%
cntr = collections.Counter(training_set.loc[training_set['X_end'] == 'ti']['y'].as_matrix())

# %%
train['len'] = train['X_beg'].map(lambda x: len(x))
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
sth = train.copy().loc[train['X_end'] == 'ti']
sth
# Out:
#             X_beg X_end       y  len
# 1749       comple    ti    to+A    6
# 3397          vie    ti  tare+V    3
# 5233         ripe    ti  tere+V    4
# 11600         liu    ti    to+N    3
# 12987      inquie    ti  tare+V    6
# 14229    incompiu    ti    to+N    8
# 14290     inesaus    ti    to+A    7
# 15600         poe    ti    ta+N    3
# 16134        argu    ti    to+A    4
# 18821         ins    ti  tare+V    3
# 18976        crip    ti  tare+V    4
# 20243        quie    ti  tare+V    4
# 20834      ciprio    ti    ta+N    6
# 24118      percuo    ti  tere+V    6
# 24232        ossu    ti    to+A    4
# 27715       epite    ti    to+N    5
# 28769      pioppe    ti    to+N    6
# 28804     pronipo    ti    te+N    7
# 29705        idio    ti    ta+A    4
# 30590        repu    ti  tare+V    4
# 30928       ulive    ti    to+N    5
# 32295        deno    ti  tare+V    4
# 33070        devo    ti    to+N    4
# 34144    mezzibus    ti    to+N    8
# 37064      patrio    ti    ta+N    6
# 40553        pilo    ti    ta+N    4
# 40920        irsu    ti    to+A    4
# 43541   mangiapre    ti    ti+N    9
# 44960       forzu    ti    to+A    5
# 45519          po    ti  tare+V    2
# ...           ...   ...     ...  ...
# 93112          mo    ti    to+N    2
# 97490      consue    ti    to+A    6
# 98692        impe    ti    to+N    4
# 99158         gre    ti    to+N    3
# 101445     diritt    ti    to+N    6
# 102911    nerboru    ti    to+A    7
# 103348    desecre    ti  tare+V    7
# 103373        spu    ti  tare+V    3
# 103669      piane    ti    ta+N    5
# 104694         se    ti    te+N    2
# 105077       coop    ti  tare+V    4
# 109107   analfabe    ti    ta+A    8
# 109114         no    ti  tare+V    2
# 113349     non-vo    ti    to+N    6
# 113786      rifiu    ti    to+N    5
# 114959    co-pilo    ti    ta+N    7
# 115811     aneddo    ti    to+N    6
# 116377       depu    ti  tare+V    4
# 116397         ve    ti    to+N    2
# 117283     agrume    ti    to+N    6
# 117298      angus    ti    to+A    5
# 1749       comple    ti  tare+V    6
# 12987      inquie    ti    to+N    6
# 20834      ciprio    ti    ta+A    6
# 44960       forzu    ti    to+N    5
# 60133      disgus    ti  tare+V    6
# 71808    interpre    ti  tare+V    8
# 77554       compu    ti  tare+V    5
# 102911    nerboru    ti    to+N    7
# 109107   analfabe    ti    ta+N    8
#
# [85 rows x 4 columns]

# %%
train.loc[training_set['X_end'] == 'ti']
# Out:
#             X_beg X_end       y  len
# 1749       comple    ti    to+A    6
# 3397          vie    ti  tare+V    3
# 5233         ripe    ti  tere+V    4
# 11600         liu    ti    to+N    3
# 12987      inquie    ti  tare+V    6
# 14229    incompiu    ti    to+N    8
# 14290     inesaus    ti    to+A    7
# 15600         poe    ti    ta+N    3
# 16134        argu    ti    to+A    4
# 18821         ins    ti  tare+V    3
# 18976        crip    ti  tare+V    4
# 20243        quie    ti  tare+V    4
# 20834      ciprio    ti    ta+N    6
# 24118      percuo    ti  tere+V    6
# 24232        ossu    ti    to+A    4
# 27715       epite    ti    to+N    5
# 28769      pioppe    ti    to+N    6
# 28804     pronipo    ti    te+N    7
# 29705        idio    ti    ta+A    4
# 30590        repu    ti  tare+V    4
# 30928       ulive    ti    to+N    5
# 32295        deno    ti  tare+V    4
# 33070        devo    ti    to+N    4
# 34144    mezzibus    ti    to+N    8
# 37064      patrio    ti    ta+N    6
# 40553        pilo    ti    ta+N    4
# 40920        irsu    ti    to+A    4
# 43541   mangiapre    ti    ti+N    9
# 44960       forzu    ti    to+A    5
# 45519          po    ti  tare+V    2
# ...           ...   ...     ...  ...
# 93112          mo    ti    to+N    2
# 97490      consue    ti    to+A    6
# 98692        impe    ti    to+N    4
# 99158         gre    ti    to+N    3
# 101445     diritt    ti    to+N    6
# 102911    nerboru    ti    to+A    7
# 103348    desecre    ti  tare+V    7
# 103373        spu    ti  tare+V    3
# 103669      piane    ti    ta+N    5
# 104694         se    ti    te+N    2
# 105077       coop    ti  tare+V    4
# 109107   analfabe    ti    ta+A    8
# 109114         no    ti  tare+V    2
# 113349     non-vo    ti    to+N    6
# 113786      rifiu    ti    to+N    5
# 114959    co-pilo    ti    ta+N    7
# 115811     aneddo    ti    to+N    6
# 116377       depu    ti  tare+V    4
# 116397         ve    ti    to+N    2
# 117283     agrume    ti    to+N    6
# 117298      angus    ti    to+A    5
# 1749       comple    ti  tare+V    6
# 12987      inquie    ti    to+N    6
# 20834      ciprio    ti    ta+A    6
# 44960       forzu    ti    to+N    5
# 60133      disgus    ti  tare+V    6
# 71808    interpre    ti  tare+V    8
# 77554       compu    ti  tare+V    5
# 102911    nerboru    ti    to+N    7
# 109107   analfabe    ti    ta+N    8
#
# [85 rows x 4 columns]

# %%
dd = []
for ending in set(test['X_end']).intersection(set(train['X_end'])):
    trg = test.loc[test['X_end'] == ending]
    trn = train.loc[train['X_end'] == ending]
    val = trn['y'].unique()
    if(len(val) == 1):
        for i in trg.index:
            test['target'][i] = val[0]
    else:
        if(len(trn['X_beg'].unique()) == 1 and trn['X_beg'].unique()[0] == ''):
            dd.append(ending)
            continue
        count_vectorizer = CountVectorizer(min_df=1, max_features=None,ngram_range=(2, 4), analyzer='char_wb', lowercase=False, binary=True) 
        X = count_vectorizer.fit_transform(trn['X_beg'])
        y = trn['y']
        algo = LogisticRegression(penalty='l1', C=0.145, class_weight='balanced')
        algo = algo.fit(X, y)
        X_train = count_vectorizer.transform(trg['X_beg'])
        target = algo.predict(X_train)
        for i, j in enumerate(trg.index):
            test['target'][j] = target[i]

# %%
exp_data.loc[train['X_end'] == 'siederebbero']
# Out:
#                   X               y PoS X_beg         X_end     X_end_new
# 75115  siederebbero      risedere+V   V        siederebbero  siederebbero
# 75115  siederebbero  soprassedere+V   V        siederebbero  siederebbero

# %%
test.loc[test['X_end'] == 'siediamo']
# Out:
#                     X   X_beg     X_end  target             y
# 21690  co-presiediamo  co-pre  siediamo  co-pre  co-preco-pre

# %%
dd
# Out:
# ['siedano', 'siederebbero', 'siederai', 'siediamo']

# %%
test['y'] = test['X_beg'] + test['target']
test
# Out:
#                       X           X_beg     X_end  target                   y
# 1              gettonan           getto       nan  nare+V         gettonare+V
# 2           incidentali       incidenta        li    le+A       incidentale+A
# 3             involtino           invol      tino  tare+V         involtare+V
# 4                 lievi             lie        vi  vare+V           lievare+V
# 5       comunistizzasse   comunistizzas        se   ere+V  comunistizzasere+V
# 6           vidimerebbe            vidi   merebbe  mare+V          vidimare+V
# 7              imbrodan         imbroda         n     n+A          imbrodan+A
# 8              strillar         strilla         r    re+V         strillare+V
# 9              cifrasti          cifras        ti    to+N          cifrasto+N
# 10         compassavano        compassa      vano  vano+A      compassavano+A
# 11                cucio            cuci         o     o+N             cucio+N
# 12           snobbavate        snobbava        te    ta+N        snobbavata+N
# 13             tesseron           tesse       ron    re+V           tessere+V
# 14            coagulare         coagula        re  rire+V       coagularire+V
# 15        somatizzarono       somatizza      rono    re+V       somatizzare+V
# 16        impoverimenti     impoverimen        ti    to+N     impoverimento+N
# 17         smungerebber     smungerebbe         r    re+V     smungerebbere+V
# 18           abbufferan         abbuffe       ran  rare+V       abbufferare+V
# 19       meravigliavano      meraviglia      vano  vano+A    meravigliavano+A
# 20            risucchiò         risucch        iò  iare+V       risucchiare+V
# 21         sesquipedale      sesquipeda        le    le+A      sesquipedale+A
# 22               timide           timid         e     e+N            timide+N
# 23          nauseassimo      nauseassim         o     o+N       nauseassimo+N
# 24            ingozzavi         ingozza        vi  vare+V       ingozzavare+V
# 25              stimino          stimin         o     o+N           stimino+N
# 26           relazionai       relaziona         i     i+A        relazionai+A
# 27           sorridessi        sorrides        si  sare+V      sorridessare+V
# 28             illumini          illumi        ni    ne+A          illumine+A
# 29        conciterebber           conci  terebber  tare+V         concitare+V
# 30         dissecheremo     dissecherem         o     o+N      dissecheremo+N
# ...                 ...             ...       ...     ...                 ...
# 29632   diagnosticarono     diagnostica      rono    re+V     diagnosticare+V
# 29633   condiscendevamo  condiscendevam         o     o+N   condiscendevamo+N
# 29634         banchetto         banchet        to    to+N         banchetto+N
# 29635       ricocessero       ricocesse        ro  rare+V     ricocesserare+V
# 29636          ammainai         ammaina         i     i+A          ammainai+A
# 29637       azzopperete       azzoppere        te    ta+N       azzoppereta+N
# 29638     scoppiettassi     scoppiettas        si  sare+V   scoppiettassare+V
# 29639  disattrezzerebbe       disattrez   zerebbe  zare+V     disattrezzare+V
# 29640         afferrate         afferra        te    ta+N         afferrata+N
# 29641           sfibran            sfib       ran  rare+V          sfibrare+V
# 29642       sgranchiamo      sgranchiam         o     o+N       sgranchiamo+N
# 29643         iniezione          iniezi       one   one+N         iniezione+N
# 29644     esecrerebbero     esecrerebbe        ro  rare+V   esecrerebberare+V
# 29645      inghirlandan     inghirlanda         n     n+A      inghirlandan+A
# 29646       damaschinai      damaschina         i     i+A       damaschinai+A
# 29647      relazionando     relazionand         o     o+N      relazionando+N
# 29648          cercaron           cerca       ron    re+V           cercare+V
# 29649      ritorcessero      ritorcesse        ro  rare+V    ritorcesserare+V
# 29650     comunicazioni      comunicazi       oni   one+N     comunicazione+N
# 29651      macchinavamo     macchinavam         o     o+N      macchinavamo+N
# 29652           murasti           muras        ti    to+N           murasto+N
# 29653      rapprendemmo     rapprendemm         o     o+N      rapprendemmo+N
# 29654      inorgogliran       inorgogli       ran    re+V       inorgoglire+V
# 29655      preconoscevi      preconosce        vi  vare+V    preconoscevare+V
# 29656       comprovaste       comprovas        te    ta+N       comprovasta+N
# 29657    disoccupazioni     disoccupazi       oni   one+N    disoccupazione+N
# 29658         preoccupò         preoccu        pò  pare+V       preoccupare+V
# 29659         spazzolan        spazzola         n     n+A         spazzolan+A
# 29660       stuzzichino      stuzzichin         o     o+N       stuzzichino+N
# 29661     impiagheremmo    impiagheremm         o     o+N     impiagheremmo+N
#
# [29661 rows x 5 columns]

# %%
test['y'][25771] = 'co-presiedere+V'
test['y'][26116] = 'co-presiedere+V'
test['y'][5153] = 'co-presiedere+V'
test['y'][26116] = 'co-presiedere+V'

# %%
answer = pd.read_csv('task2_lemmas_sample_submission', index_col=0)
answer['Category'] = test['y']
answer
# Out:
#                  Category
# 1             gettonare+V
# 2           incidentale+A
# 3             involtare+V
# 4               lievare+V
# 5      comunistizzasere+V
# 6              vidimare+V
# 7              imbrodan+A
# 8             strillare+V
# 9              cifrasto+N
# 10         compassavano+A
# 11                cucio+N
# 12           snobbavata+N
# 13              tessere+V
# 14          coagularire+V
# 15          somatizzare+V
# 16        impoverimento+N
# 17        smungerebbere+V
# 18          abbufferare+V
# 19       meravigliavano+A
# 20          risucchiare+V
# 21         sesquipedale+A
# 22               timide+N
# 23          nauseassimo+N
# 24          ingozzavare+V
# 25              stimino+N
# 26           relazionai+A
# 27         sorridessare+V
# 28             illumine+A
# 29            concitare+V
# 30         dissecheremo+N
# ...                   ...
# 29632     diagnosticare+V
# 29633   condiscendevamo+N
# 29634         banchetto+N
# 29635     ricocesserare+V
# 29636          ammainai+A
# 29637       azzoppereta+N
# 29638   scoppiettassare+V
# 29639     disattrezzare+V
# 29640         afferrata+N
# 29641          sfibrare+V
# 29642       sgranchiamo+N
# 29643         iniezione+N
# 29644   esecrerebberare+V
# 29645      inghirlandan+A
# 29646       damaschinai+A
# 29647      relazionando+N
# 29648           cercare+V
# 29649    ritorcesserare+V
# 29650     comunicazione+N
# 29651      macchinavamo+N
# 29652           murasto+N
# 29653      rapprendemmo+N
# 29654       inorgoglire+V
# 29655    preconoscevare+V
# 29656       comprovasta+N
# 29657    disoccupazione+N
# 29658       preoccupare+V
# 29659         spazzolan+A
# 29660       stuzzichino+N
# 29661     impiagheremmo+N
#
# [29661 rows x 1 columns]

# %%
answer.to_csv('task_2_submission', index_label='Id')
